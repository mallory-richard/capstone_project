# %% [markdown]
# ## Gathering Data for Analysis
# This project will be based on data from the following sources:
# a) Foursquare, which will provide location data for the southeastern Manitoba region and amenities located within it, and b) Trail Forks, which identifies the most established mountain biking trails in a region
#
# This project will take the geographic locations of popular cycling routes from Trail Forks as one dataset. It will take the geographic locations of trails from Trail Forks as another dataset. It will plot both on a map and show their location relative to area hotels.
#
# The results will provide the event organizer with a set of possible venues for a mountain bike race in southeastern Manitoba. From there, the organizer can consider other factors, such as proximity of restaurants that could potentially cater a post-race meal, or features of the possible trails (such as length of the trail or nature of the terrain) that could further inform the decision-making process to select an event venue.

# %%
#Let's start by importing the Python libraries we'll need to complete this assignment

import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
#Next, we'll upload the Client ID and Client Secret(essentially, a password) so we can connect to Foursquare

CLIENT_ID = 'KOYZEXK0ES5ID3C1WLGKIHXJBWRIS4MYQJU2SKEFS333X5DQ' # your Foursquare ID
CLIENT_SECRET = 'KHRSIOGE3FCDQ1IN2BSPIBKKAO1EH2XU3G1LIKWO3JTPG0X0' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KOYZEXK0ES5ID3C1WLGKIHXJBWRIS4MYQJU2SKEFS333X5DQ
# CLIENT_SECRET:KHRSIOGE3FCDQ1IN2BSPIBKKAO1EH2XU3G1LIKWO3JTPG0X0

# %%
#Let's use Steinbach, Manitoba, Canada, as the initial location for our analysis, letting it act as a reference point

address = 'Steinbach, Manitoba, Canada'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 49.530557 -96.69342

# %%
#Next, let's use hotel venues as the focus for our search query, and use a 200 kilometre radius to return lots of results

search_query='hotel'
radius=200000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KOYZEXK0ES5ID3C1WLGKIHXJBWRIS4MYQJU2SKEFS333X5DQ&client_secret=KHRSIOGE3FCDQ1IN2BSPIBKKAO1EH2XU3G1LIKWO3JTPG0X0&ll=49.530557,-96.69342&v=20180604&query=hotel&radius=200000&limit=30'

# %%
#Let's take a look at the results of the above query

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f00e290889e0936195fbbe1'},
#  'response': {'venues': [{'id': '4f6c709fbb3d8e65c21090e4',
#     'name': 'La Broquerie Hotel',
#     'location': {'address': '3 Pignons St',
#      'lat': 49.517595,
#      'lng': -96.502317,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.517595,
#        'lng': -96.502317}],
#      'distance': 13884,
#      'postalCode': 'R0A 0W0',
#      'cc': 'CA',
#      'city': 'La Broquerie',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['3 Pignons St',
#       'La Broquerie MB R0A 0W0',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4e2361e6e4cdf68591996eb5',
#     'name': 'St Anne Hotel Chinese Restaurant',
#     'location': {'lat': 49.67274811812094,
#      'lng': -96.65702756594861,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.67274811812094,
#        'lng': -96.65702756594861}],
#      'distance': 16044,
#      'cc': 'CA',
#      'city': 'St. Anne',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['St. Anne MB', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4d8239892fb73704a4238811',
#     'name': 'The Alouette Hotel',
#     'location': {'address': '101 2nd St. E',
#      'lat': 49.673719,
#      'lng': -96.822029,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.673719,
#        'lng': -96.822029}],
#      'distance': 18440,
#      'postalCode': 'R0A 0X0',
#      'cc': 'CA',
#      'city': 'The Pas',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['101 2nd St. E', 'The Pas MB R0A 0X0', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '50fb1e1ee4b045129eff1d63',
#     'name': 'St. Malo Hotel',
#     'location': {'lat': 49.31583,
#      'lng': -96.95473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.31583,
#        'lng': -96.95473}],
#      'distance': 30485,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d118941735',
#       'name': 'Dive Bar',
#       'pluralName': 'Dive Bars',
#       'shortName': 'Dive Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '56254264498ebd5d2e1b8916',
#     'name': 'Ste Anne Hotel',
#     'location': {'address': '103 Dawson Rd',
#      'lat': 49.6573337,
#      'lng': -96.4558156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.6573337,
#        'lng': -96.4558156}],
#      'distance': 22206,
#      'postalCode': 'R5H 1B6',
#      'cc': 'CA',
#      'city': 'Ste. Anne',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['103 Dawson Rd', 'Ste. Anne MB R5H 1B6', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '5089bebfe4b03c5c38cf257e',
#     'name': 'Richer Inn Motor Hotel',
#     'location': {'address': 'Hwy #1',
#      'crossStreet': 'At Hwy #302',
#      'lat': 49.661688796913424,
#      'lng': -96.46300646553074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.661688796913424,
#        'lng': -96.46300646553074}],
#      'distance': 22124,
#      'postalCode': 'R0E 1S0',
#      'cc': 'CA',
#      'city': 'Richer',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['Hwy #1 (At Hwy #302)',
#       'Richer MB R0E 1S0',
#       'Canada']},
#     'categories': [{'id': '5bae9231bedf3950379f89cb',
#       'name': 'Inn',
#       'pluralName': 'Inns',
#       'shortName': 'Inn',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '5220131e11d28b6cc5e1b8e0',
#     'name': 'Grande Allen Hotel',
#     'location': {'address': '601 grande all east',
#      'lat': 49.7741,
#      'lng': -96.7077,
#      'labeledLatLngs': [{'label': 'display', 'lat': 49.7741, 'lng': -96.7077}],
#      'distance': 27130,
#      'cc': 'CA',
#      'city': 'Quebec',
#      'state': 'Quebec',
#      'country': 'Canada',
#      'formattedAddress': ['601 grande all east', 'Quebec Quebec', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4d1bf509ffe98eec30ac976c',
#     'name': "Ile Des Chenes Motor Hotel - Wrangler's Bar",
#     'location': {'address': '654 Lacroix St.',
#      'crossStreet': 'Old Highway 59',
#      'lat': 49.71344683026852,
#      'lng': -96.99462253996795,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.71344683026852,
#        'lng': -96.99462253996795}],
#      'distance': 29770,
#      'postalCode': 'R0A 0T0',
#      'cc': 'CA',
#      'city': 'Ile Des Chenes',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['654 Lacroix St. (Old Highway 59)',
#       'Ile Des Chenes MB R0A 0T0',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4d0d98f8903d37040b56c555',
#     'name': 'St. Adolphe Motor Hotel',
#     'location': {'lat': 49.67118556225096,
#      'lng': -97.11127917667362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.67118556225096,
#        'lng': -97.11127917667362}],
#      'distance': 33969,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4bf3166ec440c9b63f8b0104',
#     'name': 'Curtis Gordon Motor Hotel',
#     'location': {'address': '1011 Henderson Hwy.',
#      'crossStreet': 'bwtn Leighton Ave. & McLeod Ave.',
#      'lat': 49.935307768905,
#      'lng': -97.09488283281595,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.935307768905,
#        'lng': -97.09488283281595}],
#      'distance': 53520,
#      'postalCode': 'R2K 2M2',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['1011 Henderson Hwy. (bwtn Leighton Ave. & McLeod Ave.)',
#       'Winnipeg MB R2K 2M2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '383913260'},
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4b550039f964a52049d727e3',
#     'name': 'Fort Garry Hotel',
#     'location': {'address': '222 Broadway',
#      'crossStreet': 'btw Fort & Garry',
#      'lat': 49.888156355272145,
#      'lng': -97.13685209043473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.888156355272145,
#        'lng': -97.13685209043473}],
#      'distance': 51025,
#      'postalCode': 'R3C 0R3',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['222 Broadway (btw Fort & Garry)',
#       'Winnipeg MB R3C 0R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4f771cb3e4b0f52db8c112f2',
#     'name': 'Anola Motor Hotel',
#     'location': {'address': '35160 Highway 15',
#      'crossStreet': 'Highway 12',
#      'lat': 49.88451605831887,
#      'lng': -96.63838220928201,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.88451605831887,
#        'lng': -96.63838220928201}],
#      'distance': 39601,
#      'cc': 'CA',
#      'city': 'Anola',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['35160 Highway 15 (Highway 12)',
#       'Anola MB',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4c8217b5d92ea09318274772',
#     'name': 'Northern Hotel',
#     'location': {'address': '826 Main St',
#      'lat': 49.908247,
#      'lng': -97.13367,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.908247,
#        'lng': -97.13367}],
#      'distance': 52646,
#      'postalCode': 'R2W 3N8',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['826 Main St', 'Winnipeg MB R2W 3N8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4bcd1631cc8cd13a5233c2cf',
#     'name': 'Sandman Hotel & Suites Winnipeg Airport',
#     'location': {'address': '1750 Sargent Avenue',
#      'crossStreet': '@ Century St.',
#      'lat': 49.89743471852913,
#      'lng': -97.2044081537881,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89743471852913,
#        'lng': -97.2044081537881}],
#      'distance': 54961,
#      'postalCode': 'R3H 0C7',
#      'cc': 'CA',
#      'neighborhood': 'St. James Industrial',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['1750 Sargent Avenue (@ Century St.)',
#       'Winnipeg MB R3H 0C7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4bc87b94dc55eee1c97de8ac',
#     'name': 'Clarion Hotel & Suites',
#     'location': {'address': '1445 Portage Avenue',
#      'lat': 49.881927,
#      'lng': -97.1954327,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.881927,
#        'lng': -97.1954327}],
#      'distance': 53254,
#      'postalCode': 'R3G 3P4',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['1445 Portage Avenue',
#       'Winnipeg MB R3G 3P4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4be193968dd062b58a5f3e3c',
#     'name': 'St Regis Hotel',
#     'location': {'address': '285 Smith St.',
#      'lat': 49.89381290185415,
#      'lng': -97.14264896728638,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89381290185415,
#        'lng': -97.14264896728638}],
#      'distance': 51776,
#      'postalCode': 'R3C 1K9',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['285 Smith St.', 'Winnipeg MB R3C 1K9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4b99c390f964a520ba9035e3',
#     'name': 'Royal Albert Arms Hotel',
#     'location': {'address': '48 Albert St.',
#      'lat': 49.896026,
#      'lng': -97.14049,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.896026,
#        'lng': -97.14049}],
#      'distance': 51871,
#      'postalCode': 'R3B 1E7',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['48 Albert St.', 'Winnipeg MB R3B 1E7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '5704bd03cd102771b3380467',
#     'name': 'The Nob @ St. Norbert Hotel',
#     'location': {'lat': 49.7652362,
#      'lng': -97.1535023,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.7652362,
#        'lng': -97.1535023}],
#      'distance': 42215,
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['Winnipeg MB', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4ba1417ef964a5208aa637e3',
#     'name': 'Radisson Hotel Winnipeg Downtown',
#     'location': {'address': '288 Portage Avenue',
#      'lat': 49.8937235,
#      'lng': -97.1424471,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.8937235,
#        'lng': -97.1424471}],
#      'distance': 51759,
#      'postalCode': 'R3C 0B8',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['288 Portage Avenue',
#       'Winnipeg MB R3C 0B8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '465683880'},
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '52ae6dc0498ecae318fe1ae4',
#     'name': 'Mere hotel',
#     'location': {'address': '333 Waterfront Drive',
#      'crossStreet': 'St James',
#      'lat': 49.836098459634805,
#      'lng': -97.04769851432606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.836098459634805,
#        'lng': -97.04769851432606}],
#      'distance': 42519,
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['333 Waterfront Drive (St James)',
#       'Winnipeg MB',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4b43efc7f964a5207cee25e3',
#     'name': 'Place Louis Riel All-Suite Hotel',
#     'location': {'address': '190 Smith St.',
#      'crossStreet': "at St Mary's ave",
#      'lat': 49.89050033888512,
#      'lng': -97.14061154577458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89050033888512,
#        'lng': -97.14061154577458}],
#      'distance': 51397,
#      'postalCode': 'R3C 1J8',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ["190 Smith St. (at St Mary's ave)",
#       'Winnipeg MB R3C 1J8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4dd33a0efa7611af69f02b5f',
#     'name': 'Balmoral Moter Hotel',
#     'location': {'lat': 49.898521,
#      'lng': -97.151575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.898521,
#        'lng': -97.151575}],
#      'distance': 52586,
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['Winnipeg MB', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4c4cc800a34b2d7f43ac4098',
#     'name': 'The Marlborough Hotel',
#     'location': {'address': '331 Smith St',
#      'lat': 49.89505084160788,
#      'lng': -97.14276709417284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89505084160788,
#        'lng': -97.14276709417284}],
#      'distance': 51889,
#      'postalCode': 'R3B 2G9',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['331 Smith St', 'Winnipeg MB R3B 2G9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4b516550f964a5206d4c27e3',
#     'name': 'Nor-Villa Hotel',
#     'location': {'address': '1763 Henderson Hwy.',
#      'lat': 49.95197701868482,
#      'lng': -97.07744628570491,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.95197701868482,
#        'lng': -97.07744628570491}],
#      'distance': 54441,
#      'postalCode': 'R2G 1P3',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['1763 Henderson Hwy.',
#       'Winnipeg MB R2G 1P3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '50c51f0df2e724fc323199e2',
#     'name': 'St. James Hotel',
#     'location': {'address': '1719 Portage Avenue',
#      'crossStreet': 'Queen Street',
#      'lat': 49.87946825825805,
#      'lng': -97.20720291137695,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.87946825825805,
#        'lng': -97.20720291137695}],
#      'distance': 53634,
#      'postalCode': 'R3J 0E4',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['1719 Portage Avenue (Queen Street)',
#       'Winnipeg MB R3J 0E4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'shortName': 'Liquor Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4ef2bd3346901f707ffae12a',
#     'name': 'The Central Hotel',
#     'location': {'address': '201 Melrose Ave. E.',
#      'crossStreet': '@ Kanata St.',
#      'lat': 49.8800921,
#      'lng': -96.9821381,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.8800921,
#        'lng': -96.9821381}],
#      'distance': 44113,
#      'postalCode': 'R2C 0B1',
#      'cc': 'CA',
#      'neighborhood': 'Transcona',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['201 Melrose Ave. E. (@ Kanata St.)',
#       'Winnipeg MB R2C 0B1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4c95104772dd224b5e17a091',
#     'name': 'Queen Bee Hotel',
#     'location': {'address': '2615 Pembina Hwy',
#      'crossStreet': 'Bison Dr.',
#      'lat': 49.79761162216035,
#      'lng': -97.15776346028572,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.79761162216035,
#        'lng': -97.15776346028572}],
#      'distance': 44756,
#      'postalCode': 'R3T 2H5',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['2615 Pembina Hwy (Bison Dr.)',
#       'Winnipeg MB R3T 2H5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '134255782'},
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4bb3e22ef187a593ce9413f8',
#     'name': 'Pembina motor hotel',
#     'location': {'address': '1011 Pembina Highway',
#      'lat': 49.823489941160545,
#      'lng': -97.13098978087086,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.823489941160545,
#        'lng': -97.13098978087086}],
#      'distance': 45352,
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['1011 Pembina Highway', 'Winnipeg MB', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4bdf90956198c9b65ccf17ff',
#     'name': 'Royal George Hotel',
#     'location': {'address': '123 Regent Ave W',
#      'lat': 49.89527474844028,
#      'lng': -97.00418830525555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.89527474844028,
#        'lng': -97.00418830525555}],
#      'distance': 46354,
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['123 Regent Ave W', 'Winnipeg MB', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d118941735',
#       'name': 'Dive Bar',
#       'pluralName': 'Dive Bars',
#       'shortName': 'Dive Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False},
#    {'id': '4dd980017d8b322664225367',
#     'name': 'Four Crowns Inn Hotel',
#     'location': {'address': '1030 McPhillips St.',
#      'lat': 49.93271495257905,
#      'lng': -97.16603222781264,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 49.93271495257905,
#        'lng': -97.16603222781264}],
#      'distance': 56218,
#      'postalCode': 'R2X 2K7',
#      'cc': 'CA',
#      'city': 'Winnipeg',
#      'state': 'MB',
#      'country': 'Canada',
#      'formattedAddress': ['1030 McPhillips St.',
#       'Winnipeg MB R2X 2K7',
#       'Canada']},
#     'categories': [{'id': '5bae9231bedf3950379f89cb',
#       'name': 'Inn',
#       'pluralName': 'Inns',
#       'shortName': 'Inn',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593893461',
#     'hasPerk': False}]}}

# %%
#Now let's create a dataframe based on the information above that was produced from the Foursquare query

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(20)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   import sys
#                           id                                         name  \
# 0   4f6c709fbb3d8e65c21090e4                           La Broquerie Hotel
# 1   4e2361e6e4cdf68591996eb5             St Anne Hotel Chinese Restaurant
# 2   4d8239892fb73704a4238811                           The Alouette Hotel
# 3   50fb1e1ee4b045129eff1d63                               St. Malo Hotel
# 4   56254264498ebd5d2e1b8916                               Ste Anne Hotel
# 5   5089bebfe4b03c5c38cf257e                       Richer Inn Motor Hotel
# 6   5220131e11d28b6cc5e1b8e0                           Grande Allen Hotel
# 7   4d1bf509ffe98eec30ac976c  Ile Des Chenes Motor Hotel - Wrangler's Bar
# 8   4d0d98f8903d37040b56c555                      St. Adolphe Motor Hotel
# 9   4bf3166ec440c9b63f8b0104                    Curtis Gordon Motor Hotel
# 10  4b550039f964a52049d727e3                             Fort Garry Hotel
# 11  4f771cb3e4b0f52db8c112f2                            Anola Motor Hotel
# 12  4c8217b5d92ea09318274772                               Northern Hotel
# 13  4bcd1631cc8cd13a5233c2cf      Sandman Hotel & Suites Winnipeg Airport
# 14  4bc87b94dc55eee1c97de8ac                       Clarion Hotel & Suites
# 15  4be193968dd062b58a5f3e3c                               St Regis Hotel
# 16  4b99c390f964a520ba9035e3                      Royal Albert Arms Hotel
# 17  5704bd03cd102771b3380467                  The Nob @ St. Norbert Hotel
# 18  4ba1417ef964a5208aa637e3             Radisson Hotel Winnipeg Downtown
# 19  52ae6dc0498ecae318fe1ae4                                   Mere hotel
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 1                                                  []  v-1593893461    False
# 2                                                  []  v-1593893461    False
# 3   [{'id': '4bf58dd8d48988d118941735', 'name': 'D...  v-1593893461    False
# 4   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 5   [{'id': '5bae9231bedf3950379f89cb', 'name': 'I...  v-1593893461    False
# 6   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 7   [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1593893461    False
# 8   [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1593893461    False
# 9   [{'id': '4bf58dd8d48988d1fb931735', 'name': 'M...  v-1593893461    False
# 10  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 11  [{'id': '4bf58dd8d48988d1fb931735', 'name': 'M...  v-1593893461    False
# 12  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 13  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 14  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 15  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 16  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...  v-1593893461    False
# 17  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...  v-1593893461    False
# 18  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 19  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
#
#         location.address  location.lat  location.lng  \
# 0           3 Pignons St     49.517595    -96.502317
# 1                    NaN     49.672748    -96.657028
# 2          101 2nd St. E     49.673719    -96.822029
# 3                    NaN     49.315830    -96.954730
# 4          103 Dawson Rd     49.657334    -96.455816
# 5                 Hwy #1     49.661689    -96.463006
# 6    601 grande all east     49.774100    -96.707700
# 7        654 Lacroix St.     49.713447    -96.994623
# 8                    NaN     49.671186    -97.111279
# 9    1011 Henderson Hwy.     49.935308    -97.094883
# 10          222 Broadway     49.888156    -97.136852
# 11      35160 Highway 15     49.884516    -96.638382
# 12           826 Main St     49.908247    -97.133670
# 13   1750 Sargent Avenue     49.897435    -97.204408
# 14   1445 Portage Avenue     49.881927    -97.195433
# 15         285 Smith St.     49.893813    -97.142649
# 16         48 Albert St.     49.896026    -97.140490
# 17                   NaN     49.765236    -97.153502
# 18    288 Portage Avenue     49.893724    -97.142447
# 19  333 Waterfront Drive     49.836098    -97.047699
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 49.517595, 'lng':...              13884
# 1   [{'label': 'display', 'lat': 49.67274811812094...              16044
# 2   [{'label': 'display', 'lat': 49.673719, 'lng':...              18440
# 3   [{'label': 'display', 'lat': 49.31583, 'lng': ...              30485
# 4   [{'label': 'display', 'lat': 49.6573337, 'lng'...              22206
# 5   [{'label': 'display', 'lat': 49.66168879691342...              22124
# 6   [{'label': 'display', 'lat': 49.7741, 'lng': -...              27130
# 7   [{'label': 'display', 'lat': 49.71344683026852...              29770
# 8   [{'label': 'display', 'lat': 49.67118556225096...              33969
# 9   [{'label': 'display', 'lat': 49.935307768905, ...              53520
# 10  [{'label': 'display', 'lat': 49.88815635527214...              51025
# 11  [{'label': 'display', 'lat': 49.88451605831887...              39601
# 12  [{'label': 'display', 'lat': 49.908247, 'lng':...              52646
# 13  [{'label': 'display', 'lat': 49.89743471852913...              54961
# 14  [{'label': 'display', 'lat': 49.881927, 'lng':...              53254
# 15  [{'label': 'display', 'lat': 49.89381290185415...              51776
# 16  [{'label': 'display', 'lat': 49.896026, 'lng':...              51871
# 17  [{'label': 'display', 'lat': 49.7652362, 'lng'...              42215
# 18  [{'label': 'display', 'lat': 49.8937235, 'lng'...              51759
# 19  [{'label': 'display', 'lat': 49.83609845963480...              42519
#
#    location.postalCode location.cc   location.city location.state  \
# 0              R0A 0W0          CA    La Broquerie             MB
# 1                  NaN          CA        St. Anne             MB
# 2              R0A 0X0          CA         The Pas             MB
# 3                  NaN          CA             NaN            NaN
# 4              R5H 1B6          CA       Ste. Anne             MB
# 5              R0E 1S0          CA          Richer             MB
# 6                  NaN          CA          Quebec         Quebec
# 7              R0A 0T0          CA  Ile Des Chenes             MB
# 8                  NaN          CA             NaN            NaN
# 9              R2K 2M2          CA        Winnipeg             MB
# 10             R3C 0R3          CA        Winnipeg             MB
# 11                 NaN          CA           Anola             MB
# 12             R2W 3N8          CA        Winnipeg             MB
# 13             R3H 0C7          CA        Winnipeg             MB
# 14             R3G 3P4          CA        Winnipeg             MB
# 15             R3C 1K9          CA        Winnipeg             MB
# 16             R3B 1E7          CA        Winnipeg             MB
# 17                 NaN          CA        Winnipeg             MB
# 18             R3C 0B8          CA        Winnipeg             MB
# 19                 NaN          CA        Winnipeg             MB
#
#    location.country                          location.formattedAddress  \
# 0            Canada    [3 Pignons St, La Broquerie MB R0A 0W0, Canada]
# 1            Canada                              [St. Anne MB, Canada]
# 2            Canada        [101 2nd St. E, The Pas MB R0A 0X0, Canada]
# 3            Canada                                           [Canada]
# 4            Canada      [103 Dawson Rd, Ste. Anne MB R5H 1B6, Canada]
# 5            Canada  [Hwy #1 (At Hwy #302), Richer MB R0E 1S0, Canada]
# 6            Canada       [601 grande all east, Quebec Quebec, Canada]
# 7            Canada  [654 Lacroix St. (Old Highway 59), Ile Des Che...
# 8            Canada                                           [Canada]
# 9            Canada  [1011 Henderson Hwy. (bwtn Leighton Ave. & McL...
# 10           Canada  [222 Broadway (btw Fort & Garry), Winnipeg MB ...
# 11           Canada  [35160 Highway 15 (Highway 12), Anola MB, Canada]
# 12           Canada         [826 Main St, Winnipeg MB R2W 3N8, Canada]
# 13           Canada  [1750 Sargent Avenue (@ Century St.), Winnipeg...
# 14           Canada  [1445 Portage Avenue, Winnipeg MB R3G 3P4, Can...
# 15           Canada       [285 Smith St., Winnipeg MB R3C 1K9, Canada]
# 16           Canada       [48 Albert St., Winnipeg MB R3B 1E7, Canada]
# 17           Canada                              [Winnipeg MB, Canada]
# 18           Canada  [288 Portage Avenue, Winnipeg MB R3C 0B8, Canada]
# 19           Canada  [333 Waterfront Drive (St James), Winnipeg MB,...
#
#                 location.crossStreet venuePage.id location.neighborhood
# 0                                NaN          NaN                   NaN
# 1                                NaN          NaN                   NaN
# 2                                NaN          NaN                   NaN
# 3                                NaN          NaN                   NaN
# 4                                NaN          NaN                   NaN
# 5                        At Hwy #302          NaN                   NaN
# 6                                NaN          NaN                   NaN
# 7                     Old Highway 59          NaN                   NaN
# 8                                NaN          NaN                   NaN
# 9   bwtn Leighton Ave. & McLeod Ave.    383913260                   NaN
# 10                  btw Fort & Garry          NaN                   NaN
# 11                        Highway 12          NaN                   NaN
# 12                               NaN          NaN                   NaN
# 13                     @ Century St.          NaN  St. James Industrial
# 14                               NaN          NaN                   NaN
# 15                               NaN          NaN                   NaN
# 16                               NaN          NaN                   NaN
# 17                               NaN          NaN                   NaN
# 18                               NaN    465683880                   NaN
# 19                          St James          NaN                   NaN

# %%
#Next up, let's create a dataframe containing the desired information from TrailForks

data = {'Place_Name':['Sandilands', 'St. Malo', 'Granite Groove Out', 'McGillivray Falls', 'Falcon Lake Trans Canada Trail', 'Falcon Ridge Ski Slopes', 'Crystal Springs Colony'],
        'Latitude': [49.3246, 49.3141, 50.1503, 49.8095, 49.7030, 49.690300,  49.546950],
        'Longitude': [-96.2932, -96.9536, -95.8798, -95.2379, -95.2433, -95.317180, -97.116850],
        'Green_circle': [8, 4, 3, 3, 13, 22, 2],
        'Blue_square': [12, 0, 4, 18, 0, 21, 4],
        'Black_diamond': [1, 0, 0, 0, 0, 2, 0],
        'Total_distance': [16, 5.2, 7.2, 31, 28, 32, 2.5]}

dfTrailForks = pd.DataFrame(data,columns=['Place_Name', 'Latitude', 'Longitude', 'Green_circle', 'Blue_square', 'Black_diamond', 'Total_distance'])

# %%
dfTrailForks.head(7)
# Out:
#                        Place_Name  Latitude  Longitude  Green_circle  \
# 0                      Sandilands  49.32460  -96.29320             8
# 1                        St. Malo  49.31410  -96.95360             4
# 2              Granite Groove Out  50.15030  -95.87980             3
# 3               McGillivray Falls  49.80950  -95.23790             3
# 4  Falcon Lake Trans Canada Trail  49.70300  -95.24330            13
# 5         Falcon Ridge Ski Slopes  49.69030  -95.31718            22
# 6          Crystal Springs Colony  49.54695  -97.11685             2
#
#    Blue_square  Black_diamond  Total_distance
# 0           12              1            16.0
# 1            0              0             5.2
# 2            4              0             7.2
# 3           18              0            31.0
# 4            0              0            28.0
# 5           21              2            32.0
# 6            4              0             2.5

# %%
#Before we start working with the Foursquare data in earnest, let's clean up the dataframe a little

dataframe_clean = dataframe
dataframe_clean.columns = [column.split('.')[-1] for column in dataframe_clean.columns]
dataframe_clean.head()
# Out:
#                          id                              name  \
# 0  4f6c709fbb3d8e65c21090e4                La Broquerie Hotel
# 1  4e2361e6e4cdf68591996eb5  St Anne Hotel Chinese Restaurant
# 2  4d8239892fb73704a4238811                The Alouette Hotel
# 3  50fb1e1ee4b045129eff1d63                    St. Malo Hotel
# 4  56254264498ebd5d2e1b8916                    Ste Anne Hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
# 1                                                 []  v-1593893461    False
# 2                                                 []  v-1593893461    False
# 3  [{'id': '4bf58dd8d48988d118941735', 'name': 'D...  v-1593893461    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1593893461    False
#
#          address        lat        lng  \
# 0   3 Pignons St  49.517595 -96.502317
# 1            NaN  49.672748 -96.657028
# 2  101 2nd St. E  49.673719 -96.822029
# 3            NaN  49.315830 -96.954730
# 4  103 Dawson Rd  49.657334 -96.455816
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 49.517595, 'lng':...     13884    R0A 0W0  CA
# 1  [{'label': 'display', 'lat': 49.67274811812094...     16044        NaN  CA
# 2  [{'label': 'display', 'lat': 49.673719, 'lng':...     18440    R0A 0X0  CA
# 3  [{'label': 'display', 'lat': 49.31583, 'lng': ...     30485        NaN  CA
# 4  [{'label': 'display', 'lat': 49.6573337, 'lng'...     22206    R5H 1B6  CA
#
#            city state country  \
# 0  La Broquerie    MB  Canada
# 1      St. Anne    MB  Canada
# 2       The Pas    MB  Canada
# 3           NaN   NaN  Canada
# 4     Ste. Anne    MB  Canada
#
#                                   formattedAddress crossStreet   id  \
# 0  [3 Pignons St, La Broquerie MB R0A 0W0, Canada]         NaN  NaN
# 1                            [St. Anne MB, Canada]         NaN  NaN
# 2      [101 2nd St. E, The Pas MB R0A 0X0, Canada]         NaN  NaN
# 3                                         [Canada]         NaN  NaN
# 4    [103 Dawson Rd, Ste. Anne MB R5H 1B6, Canada]         NaN  NaN
#
#   neighborhood
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
#Okay, using some geographic coordinates just outside of Steinbach, Manitoba, as our anchoring point for the map, let's produce our initial map

latitude2 = 49.3332
longitude2 = -96.0361
venues_map = folium.Map(location=[latitude2, longitude2], zoom_start=9) # generate map centred around Steinbach
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Let's add some more layers of data to the map above
# add the hotels as blue circle markers
for lat, lng in zip(dataframe_clean.lat, dataframe_clean.lng):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

#add the trails as red circle markers
for Latitude, Longitude in zip(dfTrailForks.Latitude, dfTrailForks.Longitude):
    folium.features.CircleMarker(
        [Latitude, Longitude],
        radius=5,
        color='red',
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)
    
    # display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Now let's re-create the venues map with the trail networks colour-coded based on whether the total distance of trails available is longer than 15 kilometres
data2 = {'Place_Name':['Sandilands', 'McGillivray Falls', 'Falcon Lake Trans Canada Trail', 'Falcon Ridge Ski Slopes'],
        'Latitude': [49.3246, 49.8095, 49.7030, 49.690300],
        'Longitude': [-96.2932, -95.2379, -95.2433, -95.317180],
        'Green_circle': [8, 3, 13, 22],
        'Blue_square': [12, 18, 0, 21],
        'Black_diamond': [1, 0, 0, 2],
        'Total_distance': [16, 31, 28, 32]}

dfTrailForksLong = pd.DataFrame(data2,columns=['Place_Name', 'Latitude', 'Longitude', 'Green_circle', 'Blue_square', 'Black_diamond', 'Total_distance'])

data3 = {'Place_Name':['St. Malo', 'Granite Groove Out', 'Crystal Springs Colony'],
        'Latitude': [49.3141, 50.1503, 49.546950],
        'Longitude': [-96.9536, -95.8798, -97.116850],
        'Green_circle': [4, 3, 2],
        'Blue_square': [0, 4, 4],
        'Black_diamond': [0, 0, 0],
        'Total_distance': [5.2, 7.2, 2.5]}

dfTrailForksShort = pd.DataFrame(data3,columns=['Place_Name', 'Latitude', 'Longitude', 'Green_circle', 'Blue_square', 'Black_diamond', 'Total_distance'])

# %%
#Time to generate a new map that will now show the mountain bike trails in two groups (short and long)
latitude2 = 49.3332
longitude2 = -96.0361
venues_mapFinal = folium.Map(location=[latitude2, longitude2], zoom_start=9) # generate map centred around Steinbach

# add the hotels as blue circle markers
for lat, lng in zip(dataframe_clean.lat, dataframe_clean.lng):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_mapFinal)

#add the trails that are longer than 15km as red circle markers
for Latitude, Longitude in zip(dfTrailForksLong.Latitude, dfTrailForksLong.Longitude):
    folium.features.CircleMarker(
        [Latitude, Longitude],
        radius=5,
        color='red',
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_mapFinal)
    
#add the trails that are shorter than 15km as yellow circle markers
for Latitude, Longitude in zip(dfTrailForksShort.Latitude, dfTrailForksShort.Longitude):
    folium.features.CircleMarker(
        [Latitude, Longitude],
        radius=5,
        color='yellow',
        fill = True,
        fill_color='yellow',
        fill_opacity=0.6
    ).add_to(venues_mapFinal)
    
     # display map
venues_mapFinal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# (30, 19)
